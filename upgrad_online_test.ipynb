# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# lets import the basic Libraries
import numpy as np
import pandas as pd

# for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# for jupyter notebook widgets
import ipywidgets as widgets
from ipywidgets import interact
from ipywidgets import interact_manual

# for Interactive Shells
from IPython.display import display

# %%
# setting up the chart size and background
plt.rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')

# %%
df =pd.read_csv("Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.tail()
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Genre, Age, Annual Income (k$), Spending Score (1-100)]
# Index: []

# %%
plt.title(" CustomerID ")
sns.countplot('CustomerID',data=df)
plt.show()

# %%
df['CustomerID'].value_counts()
# Out:
# 1      1
# 138    1
# 128    1
# 129    1
# 130    1
#       ..
# 70     1
# 71     1
# 72     1
# 73     1
# 200    1
# Name: CustomerID, Length: 200, dtype: int64

# %%
plt.title(" Age")
sns.countplot('Age',data=df)
plt.show()

# %%
df['Age'].value_counts()
# Out:
# 32    11
# 35     9
# 19     8
# 31     8
# 30     7
# 49     7
# 40     6
# 38     6
# 47     6
# 27     6
# 36     6
# 23     6
# 34     5
# 20     5
# 29     5
# 50     5
# 48     5
# 21     5
# 24     4
# 18     4
# 28     4
# 67     4
# 59     4
# 54     4
# 43     3
# 60     3
# 45     3
# 39     3
# 33     3
# 37     3
# 22     3
# 25     3
# 46     3
# 68     3
# 52     2
# 44     2
# 66     2
# 57     2
# 26     2
# 53     2
# 42     2
# 63     2
# 70     2
# 51     2
# 58     2
# 65     2
# 41     2
# 55     1
# 69     1
# 64     1
# 56     1
# Name: Age, dtype: int64

# %%
plt.figure(figsize=(18,8))
plt.title(" Annual Income")
sns.countplot('Annual Income (k$)',data=df)
plt.show()

# %%
df['Annual Income (k$)'].value_counts()
# Out:
# 54     12
# 78     12
# 48      6
# 71      6
# 63      6
#        ..
# 58      2
# 59      2
# 16      2
# 64      2
# 137     2
# Name: Annual Income (k$), Length: 64, dtype: int64

# %%
plt.figure(figsize=(18,8))
plt.title(" Spending Score")
sns.countplot('Spending Score (1-100)',data=df)
plt.show()

# %%
df['Spending Score (1-100)'].value_counts()
# Out:
# 42    8
# 55    7
# 46    6
# 73    6
# 35    5
#      ..
# 31    1
# 44    1
# 53    1
# 65    1
# 18    1
# Name: Spending Score (1-100), Length: 84, dtype: int64

# %%
plt.title('Age vs Annual Income')
sns.regplot(x='Age',y='Annual Income (k$)',data=df)
plt.show()

# %%
plt.title('Age vs Spending Score ')
sns.regplot(x='Age',y='Spending Score (1-100)',data=df)
plt.show()

# %%
plt.title('Annual Income vs Spending Score ')
sns.regplot(x='Annual Income (k$)',y='Spending Score (1-100)',data=df)
plt.show()

# %%
df['Age'].value_counts().plot.pie()
plt.show()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# ## Conclusion

# %%
Based on the analysis of the Mall customers dataset, we can conclude the following:

The dataset contains information about customers' gender, age, annual income, and spending score.

There are 200 entries in the dataset.

There are no missing values in the dataset.

The mean age of customers is around 38 years, with the youngest customer being 18 years old and the oldest being 70 years old.

The annual income of customers ranges from $15,000 to $137,000, with a mean of around $61,000.

The spending score of customers ranges from 1 to 99, with a mean of around 50.

The elbow method suggests that the optimal number of clusters for K-Means clustering is 5.

Based on K-Means clustering, we can group customers into 5 clusters based on their annual income and spending score: high-income, high-spending customers; high-income, low-spending customers; mid-income, mid-spending customers; low-income, high-spending customers; and low-income, low-spending customers.
    
Overall, the analysis of the Mall customers dataset can provide valuable insights for the mall owners and marketers to target their customers more effectively based on their spending habits and income levels.
